# %%
from agentlab.experiments.exp_utils import RESULTS_DIR
from agentlab.analyze import inspect_results

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load results

# %%
# # minwob GPT-4o single agent reproduced
# result_dir = RESULTS_DIR / "2024-05-28_01-16-12_generic_agent_eval_llm" #

# # workarena GPT-4o single agent mostly reproduced
# result_dir = RESULTS_DIR / "2024-05-28_01-13-04_generic_agent_eval_llm" 
# result_dir = RESULTS_DIR / "2024-05-28_01-44-29_generic_agent_eval_llm"

result_dir = inspect_results.get_most_recent_folder(RESULTS_DIR, contains=None)

print(result_dir)
result_df = inspect_results.load_result_df(result_dir)
# Out:
# /home/ubuntu/agentlab_results/2024-06-27_11-41-09_final_run
# Searching experiments directories.: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 812/812 [00:00<00:00, 520283.36it/s]
# Loading results: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 812/812 [00:00<00:00, 149935.06it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/indexes/base.py:565, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     564 try:
# --> 565     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     566 except ValueError as err:
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/construction.py:659, in sanitize_array(data, index, dtype, copy, allow_2d)
#     657             subarr = maybe_infer_to_datetimelike(subarr)
# --> 659 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     661 if isinstance(subarr, np.ndarray):
#     662     # at this point we should have dtype be None or subarr.dtype == dtype
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/construction.py:718, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     717         return result
# --> 718     raise ValueError(
#     719         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     720     )
#     721 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     722     # i.e. NumpyEADtype("O")
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (812, 1) instead
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 11
#       8 result_dir = inspect_results.get_most_recent_folder(RESULTS_DIR, contains=None)
#      10 print(result_dir)
# ---> 11 result_df = inspect_results.load_result_df(result_dir)
#
# File ~/github/AgentLab/src/agentlab/analyze/inspect_results.py:147, in load_result_df(exp_dir, progress_fn, set_index, result_df, index_white_list, index_black_list)
#     145 df = pd.DataFrame([exp_result.get_exp_record() for exp_result in result_list])
#     146 if set_index:
# --> 147     set_index_from_variables(df, index_white_list, index_black_list)
#     148 return df
#
# File ~/github/AgentLab/src/agentlab/analyze/inspect_results.py:105, in set_index_from_variables(df, index_white_list, index_black_list, task_key, force_at_leaste_one_variable)
#     103 df.drop(columns=[task_key + '_num'], inplace=True)
#     104 df.set_index([task_key] + index_variables, inplace=True)
# --> 105 df.sort_index(level=0, inplace=True, key=lambda x: x.str.extract(r'(\d+)$').astype(int))
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/frame.py:7379, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    7282 def sort_index(
#    7283     self,
#    7284     *,
#    (...)
#    7293     key: IndexKeyFunc | None = None,
#    7294 ) -> DataFrame | None:
#    7295     """
#    7296     Sort object by labels (along an axis).
#    7297
#    (...)
#    7377     d  4
#    7378     """
# -> 7379     return super().sort_index(
#    7380         axis=axis,
#    7381         level=level,
#    7382         ascending=ascending,
#    7383         inplace=inplace,
#    7384         kind=kind,
#    7385         na_position=na_position,
#    7386         sort_remaining=sort_remaining,
#    7387         ignore_index=ignore_index,
#    7388         key=key,
#    7389     )
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/generic.py:5309, in NDFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    5305 ascending = validate_ascending(ascending)
#    5307 target = self._get_axis(axis)
# -> 5309 indexer = get_indexer_indexer(
#    5310     target, level, ascending, kind, na_position, sort_remaining, key
#    5311 )
#    5313 if indexer is None:
#    5314     if inplace:
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/sorting.py:91, in get_indexer_indexer(target, level, ascending, kind, na_position, sort_remaining, key)
#      68 """
#      69 Helper method that return the indexer according to input parameters for
#      70 the sort_index method of DataFrame and Series.
#    (...)
#      85     The indexer for the new index.
#      86 """
#      88 # error: Incompatible types in assignment (expression has type
#      89 # "Union[ExtensionArray, ndarray[Any, Any], Index, Series]", variable has
#      90 # type "Index")
# ---> 91 target = ensure_key_mapped(target, key, levels=level)  # type: ignore[assignment]
#      92 target = target._sort_levels_monotonic()
#      94 if level is not None:
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/sorting.py:579, in ensure_key_mapped(values, key, levels)
#     575 try:
#     576     if isinstance(
#     577         values, Index
#     578     ):  # convert to a new Index subclass, not necessarily the same
# --> 579         result = Index(result)
#     580     else:
#     581         # try to revert to original type otherwise
#     582         type_of_values = type(values)
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/indexes/base.py:528, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     526     raise cls._raise_scalar_data_error(data)
#     527 elif hasattr(data, "__array__"):
# --> 528     return cls(np.asarray(data), dtype=dtype, copy=copy, name=name)
#     529 elif not is_list_like(data) and not isinstance(data, memoryview):
#     530     # 2022-11-16 the memoryview check is only necessary on some CI
#     531     #  builds, not clear why
#     532     raise cls._raise_scalar_data_error(data)
#
# File ~/miniconda3/envs/agentlab/lib/python3.12/site-packages/pandas/core/indexes/base.py:570, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     568         raise cls._raise_scalar_data_error(data) from err
#     569     if "Data must be 1-dimensional" in str(err):
# --> 570         raise ValueError("Index data must be 1-dimensional") from err
#     571     raise
#     572 arr = ensure_wrapped_if_datetimelike(arr)
#
# ValueError: Index data must be 1-dimensional

# %% [markdown]
# ### Various kind of reports

# %%
# basic report using summarize
# result_df = inspect_results.set_task_category_as_index(result_df)
report = inspect_results.global_report(result_df)
inspect_results.display_report(report)

# some potentially useful flag analysis
inspect_results.flag_report(report, metric="avg_reward")
# Out:
# Only one configuration is found, returning a per-task report.
# pyperclip is not installed, cannot copy to clipboard.
# <style type="text/css">
# #T_97787 th {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_97787">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97787_level0_col0" class="col_heading level0 col0" >env
# args.task
# name</th>
#       <th id="T_97787_level0_col1" class="col_heading level0 col1" >avg
# reward</th>
#       <th id="T_97787_level0_col2" class="col_heading level0 col2" >uncertainty
# reward</th>
#       <th id="T_97787_level0_col3" class="col_heading level0 col3" >avg
# raw
# reward</th>
#       <th id="T_97787_level0_col4" class="col_heading level0 col4" >avg
# steps</th>
#       <th id="T_97787_level0_col5" class="col_heading level0 col5" >n
# completed</th>
#       <th id="T_97787_level0_col6" class="col_heading level0 col6" >n
# err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97787_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97787_row0_col0" class="data row0 col0" >webarena.0</td>
#       <td id="T_97787_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_97787_row0_col2" class="data row0 col2" >0.154</td>
#       <td id="T_97787_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_97787_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_97787_row0_col5" class="data row0 col5" >1/1</td>
#       <td id="T_97787_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97787_row1_col0" class="data row1 col0" >webarena.1</td>
#       <td id="T_97787_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_97787_row1_col2" class="data row1 col2" >0.171</td>
#       <td id="T_97787_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_97787_row1_col4" class="data row1 col4" >15</td>
#       <td id="T_97787_row1_col5" class="data row1 col5" >1/1</td>
#       <td id="T_97787_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97787_row2_col0" class="data row2 col0" >webarena.10</td>
#       <td id="T_97787_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_97787_row2_col2" class="data row2 col2" >0.175</td>
#       <td id="T_97787_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_97787_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_97787_row2_col5" class="data row2 col5" >1/1</td>
#       <td id="T_97787_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97787_row3_col0" class="data row3 col0" >webarena.100</td>
#       <td id="T_97787_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_97787_row3_col2" class="data row3 col2" >0.178</td>
#       <td id="T_97787_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_97787_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_97787_row3_col5" class="data row3 col5" >1/1</td>
#       <td id="T_97787_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97787_row4_col0" class="data row4 col0" >webarena.101</td>
#       <td id="T_97787_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_97787_row4_col2" class="data row4 col2" >0.164</td>
#       <td id="T_97787_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_97787_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_97787_row4_col5" class="data row4 col5" >1/1</td>
#       <td id="T_97787_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97787_row5_col0" class="data row5 col0" >webarena.102</td>
#       <td id="T_97787_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_97787_row5_col2" class="data row5 col2" >0.167</td>
#       <td id="T_97787_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_97787_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_97787_row5_col5" class="data row5 col5" >1/1</td>
#       <td id="T_97787_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97787_row6_col0" class="data row6 col0" >webarena.103</td>
#       <td id="T_97787_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_97787_row6_col2" class="data row6 col2" >0.18</td>
#       <td id="T_97787_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_97787_row6_col4" class="data row6 col4" >15</td>
#       <td id="T_97787_row6_col5" class="data row6 col5" >1/1</td>
#       <td id="T_97787_row6_col6" class="data row6 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97787_row7_col0" class="data row7 col0" >webarena.104</td>
#       <td id="T_97787_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_97787_row7_col2" class="data row7 col2" >0.171</td>
#       <td id="T_97787_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_97787_row7_col4" class="data row7 col4" >15</td>
#       <td id="T_97787_row7_col5" class="data row7 col5" >1/1</td>
#       <td id="T_97787_row7_col6" class="data row7 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97787_row8_col0" class="data row8 col0" >webarena.105</td>
#       <td id="T_97787_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_97787_row8_col2" class="data row8 col2" >0.166</td>
#       <td id="T_97787_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_97787_row8_col4" class="data row8 col4" >15</td>
#       <td id="T_97787_row8_col5" class="data row8 col5" >1/1</td>
#       <td id="T_97787_row8_col6" class="data row8 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97787_row9_col0" class="data row9 col0" >webarena.106</td>
#       <td id="T_97787_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_97787_row9_col2" class="data row9 col2" >0.171</td>
#       <td id="T_97787_row9_col3" class="data row9 col3" >0</td>
#       <td id="T_97787_row9_col4" class="data row9 col4" >15</td>
#       <td id="T_97787_row9_col5" class="data row9 col5" >1/1</td>
#       <td id="T_97787_row9_col6" class="data row9 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_97787_row10_col0" class="data row10 col0" >webarena.107</td>
#       <td id="T_97787_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_97787_row10_col2" class="data row10 col2" >0.19</td>
#       <td id="T_97787_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_97787_row10_col4" class="data row10 col4" >15</td>
#       <td id="T_97787_row10_col5" class="data row10 col5" >1/1</td>
#       <td id="T_97787_row10_col6" class="data row10 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_97787_row11_col0" class="data row11 col0" >webarena.108</td>
#       <td id="T_97787_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_97787_row11_col2" class="data row11 col2" >0.171</td>
#       <td id="T_97787_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_97787_row11_col4" class="data row11 col4" >15</td>
#       <td id="T_97787_row11_col5" class="data row11 col5" >1/1</td>
#       <td id="T_97787_row11_col6" class="data row11 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97787_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_97787_row12_col0" class="data row12 col0" >webarena.109</td>
#       <td id="T_97787_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_97787_row12_col2" class="data row12 col2" >0.158</td>
#       <td id="T_97787_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_97787_row12_col4" class="data row12 col4" >8</td>
#       <td id="T_97787_row12_col5
# Only 1 levels in the index, cannot produce flag report.

# %%
# more stats
report_stats = inspect_results.global_report(result_df, reduce_fn=inspect_results.summarize_stats)
inspect_results.display_report(report_stats)
# Out:
# Only one configuration is found, returning a per-task report.
# pyperclip is not installed, cannot copy to clipboard.
# <style type="text/css">
# #T_00d29 th {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_00d29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d29_level0_col0" class="col_heading level0 col0" >env
# args.task
# name</th>
#       <th id="T_00d29_level0_col1" class="col_heading level0 col1" >avg
# reward</th>
#       <th id="T_00d29_level0_col2" class="col_heading level0 col2" >cum
# steps</th>
#       <th id="T_00d29_level0_col3" class="col_heading level0 col3" >cum
# n
# token
# goal</th>
#       <th id="T_00d29_level0_col4" class="col_heading level0 col4" >max
# n
# token
# goal</th>
#       <th id="T_00d29_level0_col5" class="col_heading level0 col5" >cum
# n
# token
# url</th>
#       <th id="T_00d29_level0_col6" class="col_heading level0 col6" >max
# n
# token
# url</th>
#       <th id="T_00d29_level0_col7" class="col_heading level0 col7" >cum
# n
# token
# focused
# element
# bid</th>
#       <th id="T_00d29_level0_col8" class="col_heading level0 col8" >max
# n
# token
# focused
# element
# bid</th>
#       <th id="T_00d29_level0_col9" class="col_heading level0 col9" >cum
# n
# token
# last
# action</th>
#       <th id="T_00d29_level0_col10" class="col_heading level0 col10" >max
# n
# token
# last
# action</th>
#       <th id="T_00d29_level0_col11" class="col_heading level0 col11" >cum
# n
# token
# last
# action
# error</th>
#       <th id="T_00d29_level0_col12" class="col_heading level0 col12" >max
# n
# token
# last
# action
# error</th>
#       <th id="T_00d29_level0_col13" class="col_heading level0 col13" >cum
# n
# token
# dom
# txt</th>
#       <th id="T_00d29_level0_col14" class="col_heading level0 col14" >max
# n
# token
# dom
# txt</th>
#       <th id="T_00d29_level0_col15" class="col_heading level0 col15" >cum
# n
# token
# axtree
# txt</th>
#       <th id="T_00d29_level0_col16" class="col_heading level0 col16" >max
# n
# token
# axtree
# txt</th>
#       <th id="T_00d29_level0_col17" class="col_heading level0 col17" >cum
# n
# token
# pruned
# html</th>
#       <th id="T_00d29_level0_col18" class="col_heading level0 col18" >max
# n
# token
# pruned
# html</th>
#       <th id="T_00d29_level0_col19" class="col_heading level0 col19" >cum
# openai
# total
# cost</th>
#       <th id="T_00d29_level0_col20" class="col_heading level0 col20" >max
# openai
# total
# cost</th>
#       <th id="T_00d29_level0_col21" class="col_heading level0 col21" >cum
# openai
# total
# tokens</th>
#       <th id="T_00d29_level0_col22" class="col_heading level0 col22" >max
# openai
# total
# tokens</th>
#       <th id="T_00d29_level0_col23" class="col_heading level0 col23" >cum
# openai
# completion
# tokens</th>
#       <th id="T_00d29_level0_col24" class="col_heading level0 col24" >max
# openai
# completion
# tokens</th>
#       <th id="T_00d29_level0_col25" class="col_heading level0 col25" >cum
# openai
# prompt
# tokens</th>
#       <th id="T_00d29_level0_col26" class="col_heading level0 col26" >max
# openai
# prompt
# tokens</th>
#       <th id="T_00d29_level0_col27" class="col_heading level0 col27" >cum
# n
# token
# agent
# messages</th>
#       <th id="T_00d29_level0_col28" class="col_heading level0 col28" >max
# n
# token
# agent
# messages</th>
#       <th id="T_00d29_level0_col29" class="col_heading level0 col29" >cum
# step
# elapsed</th>
#       <th id="T_00d29_level0_col30" class="col_heading level0 col30" >max
# step
# elapsed</th>
#       <th id="T_00d29_level0_col31" class="col_heading level0 col31" >cum
# agent
# elapsed</th>
#       <th id="T_00d29_level0_col32" class="col_heading level0 col32" >max
# agent
# elapsed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00d29_row0_col0" class="data row0 col0" >webarena.0</td>
#       <td id="T_00d29_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_00d29_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_00d29_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_00d29_row0_col4" class="data row0 col4" >13</td>
#       <td id="T_00d29_row0_col5" class="data row0 col5" >10</td>
#       <td id="T_00d29_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_00d29_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_00d29_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_00d29_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_00d29_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_00d29_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_00d29_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_00d29_row0_col13" class="data row0 col13" >33857</td>
#       <td id="T_00d29_row0_col14" class="data row0 col14" >33857</td>
#       <td id="T_00d29_row0_col15" class="data row0 col15" >2670</td>
#       <td id="T_00d29_row0_col16" class="data row0 col16" >2670</td>
#       <td id="T_00d29_row0_col17" class="data row0 col17" >20144</td>
#       <td id="T_00d29_row0_col18" class="data row0 col18" >20144</td>
#       <td id="T_00d29_row0_col19" class="data row0 col19" >0.023</td>
#       <td id="T_00d29_row0_col20" class="data row0 col20" >0.023</td>
#       <td id="T_00d29_row0_col21" class="data row0 col21" >4355</td>
#       <td id="T_00d29_row0_col22" class="data row0 col22" >4355</td>
#       <td id="T_00d29_row0_col23" class="data row0 col23" >153</td>
#       <td id="T_00d29_row0_col24" class="data row0 col24" >153</td>
#       <td id="T_00d29_row0_col25" class="data row0 col25" >4202</td>
#       <td id="T_00d29_row0_col26" class="data row0 col26" >4202</td>
#       <td id="T_00d29_row0_col27" class="data row0 col27" >4352</td>
#       <td id="T_00d29_row0_col28" class="data row0 col28" >4352</td>
#       <td id="T_00d29_row0_col29" class="data row0 col29" >9.154</td>
#       <td id="T_00d29_row0_col30" class="data row0 col30" >9.154</td>
#       <td id="T_00d29_row0_col31" class="data row0 col31" >6.285</td>
#       <td id="T_00d29_row0_col32" class="data row0 col32" >6.285</td>
#     </tr>
#     <tr>
#       <th id="T_00d29_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00d29_row1_col0" class="data row1 col0" >webarena.1</td>
#       <td id="T_00d29_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_00d29_row1_col2" class="data row1 col2" >15</td>
#       <td id="T_00d29_row1_col3" class="data row1 col3" >240</td>
#       <td id="T_00d29_row1_col4" class="data row1 col4" >16</td>
#       <td id="T_00d29_row1_col5" class="data row1 col5" >210</td>
#       <td id="T_00d29_row1_col6" class="data row1 col6" >15</td>
#       <td id="T_00d29_row1_col7" class="data row1 col7" >15</td>
#       <td id="T_00d29_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_00d29_row1_col9" class="data row1 col9" >84</td>
#       <td id="T_00d29_row1_col10" class="data row1 col10" >8</td>
#       <td id="T_00d29_row1_col11" class="data row1 col11" >963</td>
#       <td id="T_00d29_row1_col12" class="data row1 col12" >552</td>
#       <td id="T_00d29_row1_col13" class="data row1 col13" >566635</td>
#       <td id="T_00d29_row1_col14" class="data row1 col14" >38713</td>
#       <td id="T_00d29_row1_col15" class="data row1 col15" >22398</td>
#       <td id="T_00d29_row1_col16" class="data row1 col16" >3392</td>
#       <td id="T_00d29_row1_col17" class="data row1 col17" >363911</td>
#       <td id="T_00d29_row1_col18" class="data row1 col18" >25188</td>
#       <td id="T_00d29_row1_col19" class="data row1 col19" >0.266</td>
#       <td id="T_00d29_row1_col20" class="data row1 col20" >0.029</td>
#       <td id="T_00d29_row1_col21" class="data row1 col21" >49865</td>
#       <td id="T_00d29_row1_col22" class="data row1 col22" >5621</td>
#       <td id="T_00d29_row1_col23" class="data row1 col23" >1682</td>
#       <td id="T_00d29_row1_col24" class="data row1 col24" >181</td>
#       <td id="T_00d29_row1_col25" class="data row1 col25" >48183</td>
#       <td id="T_00d29_row1_col26" class="data row1 col26" >5505</td>
#       <td id="T_00d29_row1_col27" class="data row1 col27" >49791</td>
#       <td id="T_00d29_row1_col28" class="data row1 col28" >5629</td>
#       <td id="T_00d29_row1_col29" class="data row1 col29" >41.834</td>
#       <td id="T_00d29_row1_col30" class="data row1 col30" >9.125</td>
#       <td id="T_00d29_row1_col31" class="data row1 col31" >120.905</td>
#       <td id="T

# %%
# # breakdown by error type
# report = inspect_results.global_report(result_df, reduce_fn=inspect_results.report_different_errors)
# inspect_results.display_report(report)

# %% [markdown]
# ## Ablation study

# %%
ablation_report = inspect_results.ablation_report(result_df)
inspect_results.display_report(ablation_report)

# %% [markdown]
# ### Constants and Variables
# Prints all constants and first 3 unique values of variables

# %%
inspect_results.report_constant_and_variables(result_df, show_stack_traces=False)

# %% [markdown]
# ### Error report

# %%
print(inspect_results.error_report(result_df, max_stack_trace=5))

# %%
print(inspect_results.error_report_detailed(result_df, max_stack_trace=1))

# %%
import gradio as gr

def greet(name, intensity):
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "slider"],
    outputs=["text"],
)

# demo.launch()
demo.launch(server_port=7888)
